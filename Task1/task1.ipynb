# %% [markdown]
# ## Including necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Loading the data

# %%
df = pd.read_csv("Dataset.csv")
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# ## Data Preprocessing

# %%
df.isna().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df= df.dropna()

# %%
df.isna().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.shape
# Out:
# (9542, 21)

# %%
df = df[['Average Cost for two','Has Table booking',
       'Has Online delivery', 'Is delivering now', 'Switch to order menu',
       'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
       'Votes']]

# %%
df.shape
# Out:
# (9542, 10)

# %%
df.head()
# Out:
#    Average Cost for two Has Table booking Has Online delivery  \
# 0                  1100               Yes                  No
# 1                  1200               Yes                  No
# 2                  4000               Yes                  No
# 3                  1500                No                  No
# 4                  1500               Yes                  No
#
#   Is delivering now Switch to order menu  Price range  Aggregate rating  \
# 0                No                   No            3               4.8
# 1                No                   No            3               4.5
# 2                No                   No            4               4.4
# 3                No                   No            4               4.9
# 4                No                   No            4               4.8
#
#   Rating color Rating text  Votes
# 0   Dark Green   Excellent    314
# 1   Dark Green   Excellent    591
# 2        Green   Very Good    270
# ...

# %%
df.describe()
# Out:
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9542.000000  9542.000000       9542.000000   9542.000000
# mean            1200.326137     1.804968          2.665238    156.772060
# std            16128.743876     0.905563          1.516588    430.203324
# min                0.000000     1.000000          0.000000      0.000000
# 25%              250.000000     1.000000          2.500000      5.000000
# 50%              400.000000     2.000000          3.200000     31.000000
# 75%              700.000000     2.000000          3.700000    130.000000
# max           800000.000000     4.000000          4.900000  10934.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(14,10))

plt.subplot(3,2,1)
sns.countplot(df['Has Table booking'])

plt.subplot(3,2,2)
sns.countplot(df['Has Online delivery'])

plt.subplot(3,2,3)
sns.countplot(df['Is delivering now'])

plt.subplot(3,2,4)
sns.countplot(df['Switch to order menu'])

plt.subplot(3,2,5)
sns.countplot(df['Rating color'])

plt.subplot(3,2,6)
sns.countplot(df['Rating text'])
# Out:
# <Axes: xlabel='count', ylabel='Rating text'>

# %%
df = df.drop('Is delivering now', axis=1)
df = df.drop('Switch to order menu', axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9542 entries, 0 to 9550
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Average Cost for two  9542 non-null   int64
#  1   Has Table booking     9542 non-null   object
#  2   Has Online delivery   9542 non-null   object
#  3   Price range           9542 non-null   int64
#  4   Aggregate rating      9542 non-null   float64
#  5   Rating color          9542 non-null   object
#  6   Rating text           9542 non-null   object
#  7   Votes                 9542 non-null   int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 670.9+ KB

# %%
plt.hist(df['Aggregate rating'])
# Out:
# (array([2148.,    0.,    0.,    3.,  183., 1247., 2487., 2096., 1078.,
#          300.]),
#  array([0.  , 0.49, 0.98, 1.47, 1.96, 2.45, 2.94, 3.43, 3.92, 4.41, 4.9 ]),
#  <BarContainer object of 10 artists>)

# %%
from sklearn.preprocessing import OrdinalEncoder


OE = OrdinalEncoder(categories=[
    ['Yes','No'],
    ['Yes','No'],
    ['White','Red','Orange','Yellow','Green','Dark Green'],
    ['Not rated','Poor','Average','Good','Very Good','Excellent']
    ])

# %%
x_oe = OE.fit_transform(df[['Has Table booking','Has Online delivery', 'Rating color', 'Rating text']])

# %%
df[['Has Table booking','Has Online delivery', 'Rating color', 'Rating text']] = x_oe

# %%
df.sample(5)
# Out:
#       Average Cost for two  Has Table booking  Has Online delivery  \
# 2802                   450                1.0                  1.0
# 88                      10                1.0                  1.0
# 397                      0                1.0                  1.0
# 3615                   350                1.0                  1.0
# 1649                   600                1.0                  1.0
#
#       Price range  Aggregate rating  Rating color  Rating text  Votes
# 2802            1               3.0           2.0          2.0      4
# 88              1               3.5           3.0          3.0     67
# 397             1               3.6           3.0          3.0     59
# 3615            1               3.2           2.0          2.0      8
# 1649            2               2.9           2.0          2.0      4

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True)
plt.title("Correlation between the attributes")
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop('Aggregate rating',axis = 1), df['Aggregate rating'])

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (7156, 7)
# (2386, 7)
# (7156,)
# (2386,)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
X_train_scaled = sc.fit_transform(X_train)
X_test_scaled = sc.transform(X_test)

# %%
X_train_scaled[0]
# Out:
# array([-0.06228552,  0.36983134,  0.58810861, -0.89247105,  1.40804344,
#         1.40804344,  0.09460779])

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr1 = LinearRegression()
lr2 = LinearRegression()

# %%
lr1.fit(X_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
lr2.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(lr1.score(X_test_scaled,y_test))
# Out:
# 0.9014526281032658
# 0.9014493604313825

# %%
pred_val = lr1.predict(X_test_scaled)

# %%
from sklearn.base import r2_score
from sklearn.metrics import mean_absolute_error, mean_squared_error


lr_mae = mean_absolute_error(y_test, pred_val)
lr_mse = mean_squared_error(y_test, pred_val)
lr_r2 = r2_score(y_test, pred_val)
print(f"MAE of the linear regression model is: {lr_mae:.2f}")
print(f"MSE of the linear regression model is: {lr_mse:.2f}")
print(f"R2 score of the linear regression model is: {lr_r2:.2f}")
# Out:
# MAE of the linear regression model is: 0.42
# MSE of the linear regression model is: 0.23
# R2 score of the linear regression model is: 0.90

# %%
from sklearn.model_selection import cross_val_score


print(cross_val_score(LinearRegression(), X_test_scaled, y_test).mean())
# Out:
# 0.9005861337014206

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtree = DecisionTreeRegressor()
dtree.fit(X_train, y_train)
dtree_pred = dtree.predict(X_test)

# %%
dtree.score(X_test,y_test)
# Out:
# 0.9768913344596296

# %%
cross_val_score(DecisionTreeRegressor(),X_test,y_test).mean()
# Out:
# 0.9743371909904361

# %%
dtree_mae = mean_absolute_error(y_test, dtree_pred)
dtree_mse = mean_squared_error(y_test, dtree_pred)
dtree_r2 = r2_score(y_test, dtree_pred)
print(f"MAE of the decision tree model is: {dtree_mae:.2f}")
print(f"MSE of the decision tree model is: {dtree_mse:.2f}")
print(f"R2 score of the decision tree model is: {dtree_r2:.2f}")
# Out:
# MAE of the decision tree model is: 0.15
# MSE of the decision tree model is: 0.05
# R2 score of the decision tree model is: 0.98

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
regr = RandomForestRegressor(max_depth=4, random_state=0)
regr.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=4, random_state=0)

# %%
regr.score(X_test,y_test)
# Out:
# 0.986909488548252

# %%
cross_val_score(RandomForestRegressor(),X_train,y_train).mean()
# Out:
# 0.9841170468776701

# %%
rfg_pred = regr.predict(X_test)

# %%
rfg_mae = mean_absolute_error(y_test, rfg_pred)
rfg_mse = mean_squared_error(y_test, rfg_pred)
rfg_r2 = r2_score(y_test, rfg_pred)
print(f"MAE of the decision tree model is: {rfg_mae:.2f}")
print(f"MSE of the decision tree model is: {rfg_mse:.2f}")
print(f"R2 score of the decision tree model is: {rfg_r2:.2f}")
# Out:
# MAE of the decision tree model is: 0.12
# MSE of the decision tree model is: 0.03
# R2 score of the decision tree model is: 0.99

# %% [markdown]
# ## Best parameter values

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = { 
    'n_estimators' : [25,50,100,150],
    'max_features' : ['sqrt','log2',None],
    'max_depth' : [3,6,9],
    'max_leaf_nodes' : [3,6,9]
}

# %%
grid_search = GridSearchCV(RandomForestRegressor(), param_grid=param_grid)

# %%
grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [3, 6, 9],
#                          'max_features': ['sqrt', 'log2', None],
#                          'max_leaf_nodes': [3, 6, 9],
#                          'n_estimators': [25, 50, 100, 150]})

# %%
print(grid_search.best_estimator_)
# Out:
# RandomForestRegressor(max_depth=9, max_features=None, max_leaf_nodes=9,
#                       n_estimators=25)

# %%
model = RandomForestRegressor(max_depth=9, max_features=None, max_leaf_nodes=9,
                      n_estimators=25)

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(max_depth=9, max_features=None, max_leaf_nodes=9,
#                       n_estimators=25)

# %%
model.score(X_test,y_test)
# Out:
# 0.9870461493483191

# %%
rf_pred = model.predict(X_test)

# %%
rf_mae = mean_absolute_error(y_test, rf_pred)
rf_mse = mean_squared_error(y_test, rf_pred)
rf_r2 = r2_score(y_test, rf_pred)
print(f"MAE of the decision tree model is: {rf_mae:.2f}")
print(f"MSE of the decision tree model is: {rf_mse:.2f}")
print(f"R2 score of the decision tree model is: {rf_r2:.2f}")
# Out:
# MAE of the decision tree model is: 0.12
# MSE of the decision tree model is: 0.03
# R2 score of the decision tree model is: 0.99

# %% [markdown]
# ## Conclusion
# Random forest model achieves 99% accuracy and decision tree model achieves 98% accuracy.
#
# Restaurants with higher price range tends to have higher ratings.
